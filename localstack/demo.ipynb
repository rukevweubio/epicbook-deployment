# %%
import boto3

# Create Session (profile not needed for LocalStack)
aws_manage = boto3.session.Session()

# EC2 resource
aws_re_manage = aws_manage.resource(
    service_name="ec2",
    region_name="us-east-1",
    endpoint_url="http://localhost:4566",
    aws_access_key_id="test",
    aws_secret_access_key="test"
)

# EC2 client
aws_client = aws_manage.client(
    service_name="ec2",
    region_name="us-east-1",
    endpoint_url="http://localhost:4566",
    aws_access_key_id="test",
    aws_secret_access_key="test"
)

print(dir(aws_re_manage.instances))

# Loop through all instances
for each_in in aws_re_manage.instances.all():  # <-- plural 'instances'
    print(each_in.id, each_in.state)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_collection_cls', '_handler', '_model', '_parent', 'all', 'create_tags', 'filter', 'iterator', 'limit', 'monitor', 'page_size', 'pages', 'reboot', 'start', 'stop', 'terminate', 'unmonitor']

# %%
import boto3
from pprint  import pprint 

# Create a boto3 session (profile not needed for LocalStack)
aws_management_console = boto3.session.Session()

# EC2 resource
aws_management_resource = aws_management_console.resource(
    service_name="ec2",
    region_name="us-east-1",
    endpoint_url="http://localhost:4566",  # LocalStack API URL
    aws_access_key_id="test",
    aws_secret_access_key="test"
)

# EC2 client
aws_management_client = aws_management_console.client(
    service_name="ec2",
    region_name="us-east-1",
    endpoint_url="http://localhost:4566",  # LocalStack API URL
    aws_access_key_id="test",
    aws_secret_access_key="test"
)

# Describe instances
response = aws_management_client.describe_instances()
print(response)
# Out:
# {'Reservations': [{'ReservationId': 'r-f48a8cce5fa319c36', 'OwnerId': '000000000000', 'Groups': [], 'Instances': [{'Architecture': 'x86_64', 'BlockDeviceMappings': [{'DeviceName': '/dev/sda1', 'Ebs': {'AttachTime': datetime.datetime(2025, 11, 19, 17, 58, 18, tzinfo=tzlocal()), 'DeleteOnTermination': True, 'Status': 'in-use', 'VolumeId': 'vol-7ca65d4398837273e'}}], 'ClientToken': 'd794d0c3-679c-4ac7-b3d8-d0292024f683', 'EbsOptimized': False, 'Hypervisor': 'xen', 'NetworkInterfaces': [{'Association': {'IpOwnerId': '000000000000', 'PublicDnsName': 'ip-54-214-149-3.ec2.internal', 'PublicIp': '54.214.149.3'}, 'Attachment': {'AttachTime': datetime.datetime(2025, 11, 19, 17, 58, 18, tzinfo=tzlocal()), 'AttachmentId': 'eni-attach-14013b2c91c9dceff', 'DeleteOnTermination': False, 'DeviceIndex': 0, 'Status': 'attached', 'NetworkCardIndex': 0}, 'Description': 'Primary network interface', 'Groups': [{'GroupId': 'sg-aef43d63cffc3e831', 'GroupName': 'default'}], 'Ipv6Addresses': [], 'MacAddress': '02:00:00:11402x:21402x:102x', 'NetworkInterfaceId': 'eni-782e1c103e8bf8f57', 'OwnerId': '000000000000', 'PrivateDnsName': 'ip-10-2-200-194.ec2.internal', 'PrivateIpAddress': '10.2.200.194', 'PrivateIpAddresses': [{'Association': {'IpOwnerId': '000000000000', 'PublicDnsName': 'ip-54-214-149-3.ec2.internal', 'PublicIp': '54.214.149.3'}, 'Primary': True, 'PrivateIpAddress': '10.2.200.194'}], 'SourceDestCheck': True, 'Status': 'in-use', 'SubnetId': 'subnet-3159048d4fd10326d', 'VpcId': 'vpc-b948d4a78a41f0873', 'InterfaceType': 'interface'}], 'RootDeviceName': '/dev/sda1', 'RootDeviceType': 'ebs', 'SecurityGroups': [], 'SourceDestCheck': True, 'SriovNetSupport': 'simple', 'StateReason': {'Code': '', 'Message': ''}, 'VirtualizationType': 'paravirtual', 'HibernationOptions': {}, 'MetadataOptions': {'State': 'applied', 'HttpTokens': 'optional', 'HttpPutResponseHopLimit': 1, 'HttpEndpoint': 'enabled', 'HttpProtocolIpv6': 'disabled', 'InstanceMetadataTags': 'disabled'}, 'InstanceId': 'i-290ee2607f889796a', 'ImageId': 'ami-12345678', 'State': {'Code': 16, 'Name': 'running'}, 'PrivateDnsName': 'ip-10-2-200-194.ec2.internal', 'PublicDnsName': 'ec2-54-214-149-3.compute-1.amazonaws.com', 'StateTransitionReason': '', 'AmiLaunchIndex': 0, 'ProductCodes': [], 'InstanceType': 't2.micro', 'LaunchTime': datetime.datetime(2025, 11, 19, 17, 58, 18, tzinfo=tzlocal()), 'Placement': {'GroupName': '', 'Tenancy': 'default', 'AvailabilityZone': 'us-east-1a'}, 'KernelId': 'None', 'Monitoring': {'State': 'disabled'}, 'SubnetId': 'subnet-3159048d4fd10326d', 'VpcId': 'vpc-b948d4a78a41f0873', 'PrivateIpAddress': '10.2.200.194', 'PublicIpAddress': '54.214.149.3'}, {'Architecture': 'x86_64', 'BlockDeviceMappings': [{'DeviceName': '/dev/sda1', 'Ebs': {'AttachTime': datetime.datetime(2025, 11, 19, 17, 58, 18, tzinfo=tzlocal()), 'DeleteOnTermination': True, 'Status': 'in-use', 'VolumeId': 'vol-c992205eaa184d35e'}}], 'ClientToken': 'd794d0c3-679c-4ac7-b3d8-d0292024f683', 'EbsOptimized': False, 'Hypervisor': 'xen', 'NetworkInterfaces': [{'Association': {'IpOwnerId': '000000000000', 'PublicDnsName': 'ip-54-214-44-222.ec2.internal', 'PublicIp': '54.214.44.222'}, 'Attachment': {'AttachTime': datetime.datetime(2025, 11, 19, 17, 58, 18, tzinfo=tzlocal()), 'AttachmentId': 'eni-attach-8820a868c92c65881', 'DeleteOnTermination': False, 'DeviceIndex': 0, 'Status': 'attached', 'NetworkCardIndex': 0}, 'Description': 'Primary network interface', 'Groups': [{'GroupId': 'sg-aef43d63cffc3e831', 'GroupName': 'default'}], 'Ipv6Addresses': [], 'MacAddress': '02:00:00:11402x:19702x:4202x', 'NetworkInterfaceId': 'eni-c31b3d9a0951e1969', 'OwnerId': '000000000000', 'PrivateDnsName': 'ip-10-15-94-92.ec2.internal', 'PrivateIpAddress': '10.15.94.92', 'PrivateIpAddresses': [{'Association': {'IpOwnerId': '000000000000', 'PublicDnsName': 'ip-54-214-44-222.ec2.internal', 'PublicIp': '54.214.44.222'}, 'Primary': True, 'PrivateIpAddress': '10.15.94.92'}], 'SourceDestCheck': True, 'Status': 'in-use', 'SubnetId': 'subnet- ...
